# %% [markdown]
# <a href="https://colab.research.google.com/github/EndangSupriyadi/diamonds_prediction/blob/master/diamonds_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
